# %% [markdown]
# # Notebook Template
#
# Use this template for new notebooks in `examples/`.
#
# Sections below are required and should appear in order.

# %% [markdown]
# **Goal**: (what question does this notebook answer?)

# %%
# Reproducibility (required)
import numpy as np
import tneuro

rng = np.random.default_rng(0)
print("numpy", np.__version__)
print("tneuro", tneuro.__version__)

# %% [markdown]
# **Model/derivation summary**: (short, 3-6 lines)

# %% [markdown]
# **Implementation**: (what you implemented and why)

# %%
# Implementation code goes here.

# %% [markdown]
# **Results**: (key outputs, plots, or tables)

# %%
# Results code goes here (figures or printed summaries).

# %% [markdown]
# **Sanity checks**: (quick checks that outputs are reasonable)

# %%
# Sanity checks go here.
